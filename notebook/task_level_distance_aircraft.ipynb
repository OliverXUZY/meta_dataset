# %%
import sys
sys.path.insert(0, '/home/zhuoyan/vision/meta_dataset')
import time
import datasets
import os
import time
import json
import torch

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import torch.nn.functional as F
from collections import defaultdict

from distance_tools import load_test_features, simfunc, compute_mahalanobis_distance, MeanEmbeddingSimilarity,load_train_task_features

# %%
all = ['traffic_sign', 'mscoco', 'ilsvrc_2012', 'omniglot', 'aircraft', 'cu_birds', 'dtd', 'quickdraw', 'fungi', 'vgg_flower']
target = 'aircraft'
trsource = ['ilsvrc_2012', 'omniglot', 'aircraft', 'cu_birds', 'quickdraw', 'fungi', 'vgg_flower']

# %% [markdown]
# ## one run

# %%
features = load_test_features(irun = 0)
# Out:
# Loading image features from cached file /datadrive2/datasets/meta_dataset_taskEmb/testSet/clip/subset0_8domains_features.json [took 1.864 s]

# %%
simlarity = []
for task_id in range(350):
    task_features = load_train_task_features(task_id)
    print(task_features.shape)
# Out:
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# torch.Size([150, 512])
# ...

# %%
simlarity = []
for task_id in range(350):
    task_features = load_train_task_features(task_id)
    # print(task_features.shape)
    simlarity.append(MeanEmbeddingSimilarity(features[target], task_features))

# %%
sorted_index = sorted(range(len(simlarity)), key=lambda k: simlarity[k],reverse=True)
sorted_index[:5]
# Out:
# [175, 197, 199, 169, 177]

# %%
import json

with open('finetuning_tasks_indices2.json', 'r') as json_file:
    inidices = json.load(json_file)

print(inidices)
# Out:
# [{'source': 'quickdraw', 'task_seed': 0, 'indices': [[109, '112791'], [109, '89573'], [109, '134642'], [109, '8586'], [109, '36001'], [109, '27732'], [109, '31876'], [109, '33289'], [109, '123119'], [109, '99612'], [71, '96168'], [71, '99894'], [71, '35070'], [71, '19463'], [71, '81576'], [71, '36476'], [71, '59926'], [71, '27211'], [71, '26105'], [71, '105942'], [37, '106563'], [37, '100443'], [37, '35526'], [37, '31914'], [37, '51487'], [37, '54601'], [37, '108665'], [37, '112252'], [37, '42074'], [37, '115257'], [74, '116316'], [74, '33159'], [74, '94675'], [74, '11793'], [74, '2329'], [74, '45039'], [74, '21548'], [74, '28394'], [74, '18241'], [74, '79939'], [108, '45630'], [108, '78559'], [108, '20922'], [108, '41744'], [108, '100921'], [108, '105031'], [108, '28785'], [108, '69726'], [108, '98107'], [108, '9458'], [228, '39807'], [228, '45979'], [228, '161478'], [228, '98145'], [228, '40654'], [228, '90771'], [228, '107783'], [228, '112787'], [228, '57853'], [228, '146466'], [1
# ...

# %%
filtered_index = []
if target in trsource:
    for i in sorted_index:
        if inidices[i]['source'] != target:
            filtered_index.append(i)
filtered_index
# Out:
# [100,
#  139,
#  107,
#  141,
#  124,
#  146,
#  136,
#  102,
#  111,
#  103,
#  121,
#  109,
#  149,
#  125,
#  106,
#  147,
#  140,
#  113,
#  110,
#  142,
#  101,
#  143,
#  105,
#  127,
#  114,
#  132,
#  131,
#  138,
#  116,
#  118,
#  137,
#  145,
#  108,
#  119,
#  144,
#  117,
#  128,
#  104,
#  120,
#  134,
#  129,
#  112,
#  148,
#  122,
#  126,
#  133,
#  123,
#  115,
#  130,
#  135,
#  275,
#  260,
#  265,
#  299,
#  257,
#  286,
#  281,
#  274,
#  280,
#  259,
#  287,
#  294,
#  272,
#  284,
#  273,
#  261,
#  297,
#  290,
#  250,
#  293,
#  291,
#  292,
#  288,
#  296,
#  269,
#  253,
#  262,
#  283,
#  267,
#  279,
#  278,
#  285,
#  251,
#  258,
#  256,
#  276,
#  268,
#  263,
#  277,
#  298,
#  264,
#  271,
#  14,
#  25,
#  9,
#  41,
#  252,
#  282,
#  37,
#  2,
#  36,
#  6,
#  40,
#  49,
#  270,
#  3,
#  17,
#  254,
#  8,
#  34,
#  21,
#  39,
#  44,
#  295,
#  255,
#  266,
#  4,
#  0,
#  12,
#  7,
#  33,
#  29,
#  19,
#  1,
#  43,
#  289,
#  69,
#  31,
#  10,
#  5,
# ...

# %%
sorted_index[50:]
# Out:
# [100,
#  139,
#  107,
#  141,
#  124,
#  146,
#  136,
#  102,
#  111,
#  103,
#  121,
#  109,
#  149,
#  125,
#  106,
#  147,
#  140,
#  113,
#  110,
#  142,
#  101,
#  143,
#  105,
#  127,
#  114,
#  132,
#  131,
#  138,
#  116,
#  118,
#  137,
#  145,
#  108,
#  119,
#  144,
#  117,
#  128,
#  104,
#  120,
#  134,
#  129,
#  112,
#  148,
#  122,
#  126,
#  133,
#  123,
#  115,
#  130,
#  135,
#  275,
#  260,
#  265,
#  299,
#  257,
#  286,
#  281,
#  274,
#  280,
#  259,
#  287,
#  294,
#  272,
#  284,
#  273,
#  261,
#  297,
#  290,
#  250,
#  293,
#  291,
#  292,
#  288,
#  296,
#  269,
#  253,
#  262,
#  283,
#  267,
#  279,
#  278,
#  285,
#  251,
#  258,
#  256,
#  276,
#  268,
#  263,
#  277,
#  298,
#  264,
#  271,
#  14,
#  25,
#  9,
#  41,
#  252,
#  282,
#  37,
#  2,
#  36,
#  6,
#  40,
#  49,
#  270,
#  3,
#  17,
#  254,
#  8,
#  34,
#  21,
#  39,
#  44,
#  295,
#  255,
#  266,
#  4,
#  0,
#  12,
#  7,
#  33,
#  29,
#  19,
#  1,
#  43,
#  289,
#  69,
#  31,
#  10,
#  5,
# ...

# %%
a = [1,2]
if a:
    print("a")
else:
    print("b")
# Out:
# a
